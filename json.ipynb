# %% [markdown]
# **JSON(JavaScript Object Notation)** is a lightweight data-interchange format that easy for humans to read and write.

# %%
my_json_string = """{
   "article": [

      {
         "id":"01",
         "language": "JSON",
         "edition": "first",
         "author": "Derrick Mwiti"
      },

      {
         "id":"02",
         "language": "Python",
         "edition": "second",
         "author": "Derrick Mwiti"
      }
   ],

   "blog":[
   {
       "name": "Datacamp",
       "URL":"datacamp.com"
   }
   ]
}
"""

# %% [markdown]
# ![Screenshot%20%28278%29.png](attachment:Screenshot%20%28278%29.png)

# %%
import json   #Converting JSON to Python Objects using loads
json.loads(my_json_string)
# Out:
# {'article': [{'id': '01',
#    'language': 'JSON',
#    'edition': 'first',
#    'author': 'Derrick Mwiti'},
#   {'id': '02',
#    'language': 'Python',
#    'edition': 'second',
#    'author': 'Derrick Mwiti'}],
#  'blog': [{'name': 'Datacamp', 'URL': 'datacamp.com'}]}

# %%
for item in json.loads(my_json_string)['article']:  # iteration through each article
    print(item['language'])
# Out:
# JSON
# Python

# %%
type(json.loads(my_json_string))   # checking the type after laoding json string to python object
# Out:
# dict

# %%
print(dir(json),end=' ')  # different methods available  with json
# Out:
# ['JSONDecodeError', 'JSONDecoder', 'JSONEncoder', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_default_decoder', '_default_encoder', 'codecs', 'decoder', 'detect_encoding', 'dump', 'dumps', 'encoder', 'load', 'loads', 'scanner']

# %%
with open('test_file.json', 'w') as file:   #dumping json file
    # here dump is used for file only
    json.dump(my_json_string, file)

# %%
with open('test_file.json', 'r') as j:  # reading json file 
    #load is used to read file
    json_data = json.load(j)
    print(json_data)
# Out:
# {
#    "article": [
#
#       {
#          "id":"01",
#          "language": "JSON",
#          "edition": "first",
#          "author": "Derrick Mwiti"
#       },
#
#       {
#          "id":"02",
#          "language": "Python",
#          "edition": "second",
#          "author": "Derrick Mwiti"
#       }
#    ],
#
#    "blog":[
#    {
#        "name": "Datacamp",
#        "URL":"datacamp.com"
#    }
#    ]
# }

# %%
#lets read this json file
with open(r'C:\Users\Sabin Sapkota\Desktop\states.json','r') as f:
    s=json.load(f)
    print(s)
# Out:
# {'states': [{'name': 'Alabama', 'abbreviation': 'AL', 'area_codes': ['205', '251', '256', '334', '938']}, {'name': 'Alaska', 'abbreviation': 'AK', 'area_codes': ['907']}, {'name': 'Arizona', 'abbreviation': 'AZ', 'area_codes': ['480', '520', '602', '623', '928']}, {'name': 'Arkansas', 'abbreviation': 'AR', 'area_codes': ['479', '501', '870']}, {'name': 'California', 'abbreviation': 'CA', 'area_codes': ['209', '213', '310', '323', '408', '415', '424', '442', '510', '530', '559', '562', '619', '626', '628', '650', '657', '661', '669', '707', '714', '747', '760', '805', '818', '831', '858', '909', '916', '925', '949', '951']}, {'name': 'Colorado', 'abbreviation': 'CO', 'area_codes': ['303', '719', '720', '970']}, {'name': 'Connecticut', 'abbreviation': 'CT', 'area_codes': ['203', '475', '860', '959']}, {'name': 'Delaware', 'abbreviation': 'DE', 'area_codes': ['302']}, {'name': 'Florida', 'abbreviation': 'FL', 'area_codes': ['239', '305', '321', '352', '386', '407', '561', '727', '754', 
# ...

# %%
#lets modify above file by deleting area codes
with open(r'C:\Users\Sabin Sapkota\Desktop\states.json','r') as f:
    s=json.load(f)
    for item in s['states']:
        del (item['area_codes']) # deleting area code  
with open('new.json','w') as f:   # wrtite to new file with  2 indent and setting sorting keys equal to true
     json.dump(s,f,sort_keys=True,indent=2)

# %%
# lest check whether area code is deleted or not
with open('new.json') as f:
    print(json.load(f))
# Out:
# {'states': [{'abbreviation': 'AL', 'name': 'Alabama'}, {'abbreviation': 'AK', 'name': 'Alaska'}, {'abbreviation': 'AZ', 'name': 'Arizona'}, {'abbreviation': 'AR', 'name': 'Arkansas'}, {'abbreviation': 'CA', 'name': 'California'}, {'abbreviation': 'CO', 'name': 'Colorado'}, {'abbreviation': 'CT', 'name': 'Connecticut'}, {'abbreviation': 'DE', 'name': 'Delaware'}, {'abbreviation': 'FL', 'name': 'Florida'}, {'abbreviation': 'GA', 'name': 'Georgia'}, {'abbreviation': 'HI', 'name': 'Hawaii'}, {'abbreviation': 'ID', 'name': 'Idaho'}, {'abbreviation': 'IL', 'name': 'Illinois'}, {'abbreviation': 'IN', 'name': 'Indiana'}, {'abbreviation': 'IA', 'name': 'Iowa'}, {'abbreviation': 'KS', 'name': 'Kansas'}, {'abbreviation': 'KY', 'name': 'Kentucky'}, {'abbreviation': 'LA', 'name': 'Louisiana'}, {'abbreviation': 'ME', 'name': 'Maine'}, {'abbreviation': 'MD', 'name': 'Maryland'}, {'abbreviation': 'MA', 'name': 'Massachusetts'}, {'abbreviation': 'MI', 'name': 'Michigan'}, {'abbreviation': 'MN', 'name
# ...

# %%
# converting json file to data frame
import pandas as pd
data = pd.read_json("https://api.github.com/users")
df = pd.DataFrame(data)
df
# Out:
#            login  id                   node_id  \
# 0        mojombo   1              MDQ6VXNlcjE=
# 1        defunkt   2              MDQ6VXNlcjI=
# 2        pjhyett   3              MDQ6VXNlcjM=
# 3         wycats   4              MDQ6VXNlcjQ=
# 4       ezmobius   5              MDQ6VXNlcjU=
# 5           ivey   6              MDQ6VXNlcjY=
# 6        evanphx   7              MDQ6VXNlcjc=
# 7        vanpelt  17              MDQ6VXNlcjE3
# 8   wayneeseguin  18              MDQ6VXNlcjE4
# 9        brynary  19              MDQ6VXNlcjE5
# 10    kevinclark  20              MDQ6VXNlcjIw
# 11  technoweenie  21              MDQ6VXNlcjIx
# 12   macournoyer  22              MDQ6VXNlcjIy
# 13         takeo  23              MDQ6VXNlcjIz
# 14         caged  25              MDQ6VXNlcjI1
# 15      topfunky  26              MDQ6VXNlcjI2
# 16  anotherjesse  27              MDQ6VXNlcjI3
# 17        roland  28              MDQ6VXNlcjI4
# 18         lukas  29              MDQ6VXNlcjI5
# ...

# %%
df.shape
# Out:
# (30, 18)
