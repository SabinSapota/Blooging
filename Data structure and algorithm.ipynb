# %% [markdown]
# # Data Structure and algorithm

# %% [markdown]
# **Data structure** is a particular way of organising Data in  a Computer so that it can be used effectively.

# %% [markdown]
# **Big O notation** Big O notation is used to measure how running time or space requirement for program goes as input size grows

# %% [markdown]
# ![Screenshot%20%28236%29.png](attachment:Screenshot%20%28236%29.png)

# %% [markdown]
# ![Screenshot%20%28239%29.png](attachment:Screenshot%20%28239%29.png)

# %% [markdown]
# ![Screenshot%20%28242%29.png](attachment:Screenshot%20%28242%29.png)

# %% [markdown]
# ![Screenshot%20%28243%29.png](attachment:Screenshot%20%28243%29.png)

# %% [markdown]
# # Linked list implementation in python

# %%
class Node:
    def __init__(self,data):   # we are creating node
        self.data=data
        self.ref=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def printlist(self):
        if self.head is None:
            print('linkedlist is empty')
        else:
            n=self.head
            while n is not None:
                
                print(n.data,'-->',end=' ')
                n=n.ref
                
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node
        
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
            
    def delete_begin(self):
        if self.head is None:
            print('Linkedlist is empty')
        else:
            self.head=self.head.ref
    
    def delete_end(self):
        if self.head is None:
            print('Linkedlist is empty')
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
    def add_after(self,data,x):
        n=self.head
        while n is not None:
            if x==n.data:
                break
            n=n.ref
        if n is None:
            print('Node is not found')
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
            
    def delete_by_value(self,x):
        if self.head is None:
            print('linked list is empty')
            return
        if x==self.head.data:
            self.head=self.head.ref
            return
        n=self.head
        while n.ref is not None:
            if x==n.ref.data:
                break
            n=n.ref
        if n.ref is None:
            print('element is not found in linked list')
        else:
            n.ref=n.ref.ref
            
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print('Linkedlist is not empty')

# %%
ll=LinkedList()

# %%
ll.add_begin(15)

# %%
ll.insert_empty(12)

# %%
ll.add_begin(7)

# %%
ll.add_end(13)

# %%
ll.add_end(23)

# %%
ll.printlist()
# Out:
# 12 -->

# %%
ll.delete_by_value(15)

# %%
ll.delete_begin()

# %%
ll.printlist()
# Out:
# 7 --> 15 --> 13 --> 23 -->

# %%
ll.delete_end()

# %%
ll.printlist()
# Out:
# 7 --> 15 --> 10 --> 100 --> 13 --> 23 -->

# %%
ll.add_after(10,1)
# Out:
# Node is not found

# %% [markdown]
# # Double Linked List

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nref=None  # next cell reference
        
        self.pref=None    #previous cell reference
class Doublell:
    def __init__(self):
        self.head=None
    def printll(self):
        
        if self.head is None:
            print('Linkedlist is empty')
        else:
            n=self.head
            while n is not None:
                print(n.data,'-->',end=' ')
                n=n.nref
    def printll_reverse(self):
        print()
        if self.head is None:
            print('Linkedlist is empty')
        else:
            n=self.head
            while  n.nref is not None:
                n=n.nref
            while n is not None:
                print(n.data,'-->',end=' ')
                n=n.pref
                
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print('Linkedlist is not empty')
            
    def insert_begin(self,data):
        
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            new_node.nref=self.head
            self.head.pref=new_node
            self.head=new_node
    def insert_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.nref is not None:
                n=n.nref
            n.nref=new_node
            new_node.pref=n
            
    def insert_after(self,data,x):
        if self.head is None:
            print('Linkedlist is empty')
        else:
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print('Given Node does not exist in linked list')
            else:
                new_node=Node(data)
                new_node.nref=n.nref
                new_node.pref=n
                if n.nref is not None:
                    n.nref.pref=new_node
                n.nref=new_node
    def insert_before(self,data,x):
        if self.head is None:
            print('Linkedlist is empty')
        else:
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print('Given Node does not exist in linked list')
            else:
                new_node=Node(data)
                new_node.nref=n
                new_node.pref=n.pref
                if n.pref is not None:
                    n.pref.nref=new_node
                else:
                    self.head=new_node
                n.pref=new_node
                
    def delete_begin(self):
        if self.head is None:
            print('Linkedlist is empty')
            return
        if self.head.nref is None:
            self.head=None
            print('Linked list is empty after deleting ')
        else:
            self.head=self.head.nref
            self.head.pref=None
            
    def delete_end(self):
        if self.head is None:
            print('Linkedlist is empty')
            return
        if self.head.nref is None:
            self.head=None
            print('Linked list is empty after deleting ')
        else:
            n=self.head
            while n.nref is not None:
                n=n.nref
            n.pref.nref=None
            
            
    def delete_by_value(self,x):
        if self.head is None:
            print('Linked list is empty')
            return
        if self.head.nref is None:
            if self.head.data==x:
                self.head=None
            else:
                print('Node is not present in the linkedlist')
            return
        # for deleting first node
        if self.head.data==x:
            self.head=self.head.nref
            self.head.pref=None
            return
        n=self.head
        while n.nref is not None:
            if x==n.data:
                break
            n=n.nref
        if n.nref is not None:
            n.pref.nref=n.nref
            n.nref.pref=n.pref
        else:
            if x==n.data:
                n.pref.nref=None
            else:
                print('data is not present in the linked lisst')

# %%
ll=Doublell()

# %%
ll.printll_reverse()
# Out:
# Linkedlist is empty

# %%
ll.insert_begin(51)

# %%
ll.insert_end(131)

# %%
ll.printll()
# Out:
# 51 --> 13 --> 131 -->

# %%
ll.delete_by_value(13)

# %%
ll.printll()
# Out:
# 51 --> 131 -->

# %%
ll.delete_end()
# Out:
# Linked list is empty after deleting

# %%
ll.delete_begin()
# Out:
# Linked list is empty after deleting

# %%
ll.insert_empty(56)
# Out:
# Linkedlist is not empty

# %%
ll.insert_after(4,45)

# %%
ll.insert_before(23,45)

# %% [markdown]
# # Stack

# %% [markdown]
# - push:-add element
# - pop:-remove element

# %%
stack=[]
def pop():
    if  not stack:
        print('stack is empty')
    else:
        e=stack.pop()
        print(f'removed element is {e}')
        print(stack)
def push():
    if len(stack)==m:
        print('stack is overflow')
    else:
        ele=input('enter the element')
        stack.append(ele)
        print(stack)
    
m=int(input('size of the stack'))
while True:
    print('Enter your choice,1:- for push,2:- for pop ,3:- for break')
    n=int(input(''))
    if n==1:
        push()
    elif n==2:
        pop()
    elif n==3:
        break
    else:
        print('please enter the correct  choice')
# Out:
# size of the stack3
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 1
# enter the element23
# ['23']
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 1
# enter the element45
# ['23', '45']
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 1
# enter the element56
# ['23', '45', '56']
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 1
# stack is overflow
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 2
# removed element is 56
# ['23', '45']
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 2
# removed element is 45
# ['23']
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 2
# removed element is 23
# []
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 2
# stack is empty
# Enter your choice,1:- for push,2:- for pop ,3:- for break
# 3

# %%
from collections import deque

# %%
print(dir(deque),end=' ')  # methods available in stack
# Out:
# ['__add__', '__bool__', '__class__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'appendleft', 'clear', 'copy', 'count', 'extend', 'extendleft', 'index', 'insert', 'maxlen', 'pop', 'popleft', 'remove', 'reverse', 'rotate']

# %%
stack=deque()
stack.append('a')

# %%
stack.append('b')

# %%
stack.append('c')

# %%
stack.pop()
# Out:
# 'c'

# %%
stack
# Out:
# deque(['a', 'b'])

# %% [markdown]
# # stack implementation using class

# %%
class stack:
    def __init__(self):
        self.container=deque()
    def push(self,ele):
        return self.container.append(ele)
    def pop(self):
        return self.container.pop()
    def peek(self):
        """peek to look at the top of the stack"""
        return self.container[-1]
    def is_empty(self):
        return len(self.container)==0
    def size(self):
        return len(self.container)
    def printing(self):
        print(self.container)

# %%
s=stack()

# %%
s.push(5)

# %%
s.pop()
# Out:
# 5

# %%
s.peek()
# Out:
# 4

# %%
s.is_empty()
# Out:
# False

# %%
s.printing()
# Out:
# deque([7, 4])

# %% [markdown]
# # Queue

# %% [markdown]
# - **enqueue**:-processing of adding
# - **dequeue**:-processing of removing

# %%
queue=[]
def enqueue():
    ele=input('enter element')
    queue.append(ele)
    
def dequeue():
    if not queue:
        print('queue is empty')
    else:
        e=queue.pop(0)
        print('removed element is',e)
        
def display():
    print(queue)
       
while True:
    print('1:- for enque,2:- for deque,3:-for exist')
    n=int(input('Enter your choice'))
    if n==1:
        enqueue()
    elif n==2:
        dequeue()
    elif n==3:
        display()
        
    elif n==4:
        break
    else:
        print('please enter proper number')
# Out:
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice1
# enter element5
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice1
# enter element6
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice1
# enter element77
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice3
# ['5', '6', '77']
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice2
# removed element is 5
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice3
# ['6', '77']
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice2
# removed element is 6
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice3
# ['77']
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice2
# removed element is 77
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice2
# queue is empty
# 1:- for enque,2:- for deque,3:-for exist
# Enter your choice4

# %%
from collections import deque

class Queue:
    def __init__(self):
        self.container=deque()
    def enque(self,ele):
        return self.container.appendleft(ele)
    def deque(self):
        return self.container.pop()
    def is_empty(self):
        return self.len(container==0)
    def size(self):
        return len(self.container)
    def printing(self):
        print(self.container)

# %%
q=Queue()

# %%
q.enque(212)

# %%
q.printing()
# Out:
# deque([212, 21, 2])

# %%
q.deque()
# Out:
# 2

# %%
q.container
# Out:
# deque([212, 21])

# %%
q.size()
# Out:
# 2

# %% [markdown]
# # Hash Table

# %%
def hash_key(key):
    h=0
    for char in key:
        h+=ord(char)
    return h%100   # 100 is size of the list

# %%
hash_key('march 17')
# Out:
# 59

# %%
class HashTable:
    def __init__(self):
        self.max=100
        self.arr=[None for i in range(self.max)]
        
    def hash_key(self,key):
        self.key=key
        h=0
        for char in self.key:
            h+=ord(char)
        return h% self.max
    def add_value(self,key,value):
        h=self.hash_key(key)
        self.arr[h]=value
    def get_value(self,key):
        
        h=self.hash_key(key)
        return self.arr[h]

# %%
t=HashTable()
t.hash_key('march 6')
# Out:
# 9

# %%
t.get_value('march 6')
# Out:
# 120

# %%
t.add_value('march 6',120)

# %%
t.arr
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  120,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
class HashTable:
    def __init__(self):
        self.max=100
        self.arr=[None for i in range(self.max)]
        
    def hash_key(self,key):
        self.key=key
        h=0
        for char in self.key:
            h+=ord(char)
        return h% self.max
    def __setitem__(self,key,value):
        h=self.hash_key(key)
        self.arr[h]=value
    def __getitem__(self,key):
        
        h=self.hash_key(key)
        return self.arr[h]
    def __delitem__(self,key):
        h=self.hash_key(key)
        self.arr[h]=None

# %%
t=HashTable()

# %%
t['march 6']
# Out:
# 123

# %%
t['march 6']=123

# %%
t['march 8']=234

# %%
del t['march 6']

# %%
t.arr
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  234,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
t['march 6']
# Out:
# 123

# %% [markdown]
# # Handling coolsion in Hash Map

# %%
class HashTable:
    def __init__(self):
        self.max=10
        self.arr=[[] for i in range(self.max)]
        
    def hash_key(self,key):
        self.key=key
        h=0
        for char in self.key:
            h+=ord(char)
        return h% self.max
    def __setitem__(self,key,value):
        h=self.hash_key(key)
        self.arr[h]=value
    def __getitem__(self,key,value):
        
        h=self.hash_key(key)
        found=False
        for index,element in enumerate(self.arr[h]):
            if len(element)==2 and element[0]==key:
                self.arr[h][index]=(key,value)
                found=True
                break
        if not found:
            self.arr[h].append((key,value))
        
        
        
       
    def __delitem__(self,key):
        h=self.hash_key(key)
        self.arr[h]=None

# %%
t=HashTable()
t.hash_key('march 17')
# Out:
# 9

# %%
t['march 6']=218
t['march 17']=231

# %%
t.arr
# Out:
# [[], [], [], [], [], [], [], [], [], 231]

# %% [markdown]
# # Sorting by python function

# %%
my_list=[
    {'First Name': 'Raj', 'Last Name': 'Nayyar'},
    {'First Name': 'Suraj', 'Last Name': 'Sharma'},
    {'First Name': 'Karan', 'Last Name': 'Kumar'},
    {'First Name': 'Jade', 'Last Name': 'Canary'},
    {'First Name': 'Raj', 'Last Name': 'Thakur'},
    {'First Name': 'Raj', 'Last Name': 'Sharma'},
    {'First Name': 'Kiran', 'Last Name': 'Kamla'},
    {'First Name': 'Armaan', 'Last Name': 'Kumar'},
    {'First Name': 'Jaya', 'Last Name': 'Sharma'},
    {'First Name': 'Ingrid', 'Last Name': 'Galore'},
    {'First Name': 'Jaya', 'Last Name': 'Seth'},
    {'First Name': 'Armaan', 'Last Name': 'Dadra'},
    {'First Name': 'Ingrid', 'Last Name': 'Maverick'},
    {'First Name': 'Aahana', 'Last Name': 'Arora'}
]

# %%
sorted(my_list,key=lambda x:(x['First Name'],x['Last Name']))
# Out:
# [{'First Name': 'Aahana', 'Last Name': 'Arora'},
#  {'First Name': 'Armaan', 'Last Name': 'Dadra'},
#  {'First Name': 'Armaan', 'Last Name': 'Kumar'},
#  {'First Name': 'Ingrid', 'Last Name': 'Galore'},
#  {'First Name': 'Ingrid', 'Last Name': 'Maverick'},
#  {'First Name': 'Jade', 'Last Name': 'Canary'},
#  {'First Name': 'Jaya', 'Last Name': 'Seth'},
#  {'First Name': 'Jaya', 'Last Name': 'Sharma'},
#  {'First Name': 'Karan', 'Last Name': 'Kumar'},
#  {'First Name': 'Kiran', 'Last Name': 'Kamla'},
#  {'First Name': 'Raj', 'Last Name': 'Nayyar'},
#  {'First Name': 'Raj', 'Last Name': 'Sharma'},
#  {'First Name': 'Raj', 'Last Name': 'Thakur'},
#  {'First Name': 'Suraj', 'Last Name': 'Sharma'}]

# %%
elements = [
        { 'name': 'mona',   'transaction_amount': 1000, 'device': 'iphone-10'},
        { 'name': 'dhaval', 'transaction_amount': 400,  'device': 'google pixel'},
        { 'name': 'kathy',  'transaction_amount': 200,  'device': 'vivo'},
        { 'name': 'aamir',  'transaction_amount': 800,  'device': 'iphone-8'},
    ]

# %%
def sorting(s):
    return sorted(elements,key=lambda x:x[s])

# %%
sorting('transaction_amount')
# Out:
# [{'name': 'kathy', 'transaction_amount': 200, 'device': 'vivo'},
#  {'name': 'dhaval', 'transaction_amount': 400, 'device': 'google pixel'},
#  {'name': 'aamir', 'transaction_amount': 800, 'device': 'iphone-8'},
#  {'name': 'mona', 'transaction_amount': 1000, 'device': 'iphone-10'}]

# %%
sorting('name')
# Out:
# [{'name': 'aamir', 'transaction_amount': 800, 'device': 'iphone-8'},
#  {'name': 'dhaval', 'transaction_amount': 400, 'device': 'google pixel'},
#  {'name': 'kathy', 'transaction_amount': 200, 'device': 'vivo'},
#  {'name': 'mona', 'transaction_amount': 1000, 'device': 'iphone-10'}]

# %% [markdown]
# # Bubble Sort

# %%
my_list=[34,21,5,1,356,17,9,47]

# %% [markdown]
# - Time Complexity-O(n2)
# -  Space Complexity-O(1)

# %%
def bubble_sort(my_list):
    for i in range(len(my_list)):
        swapped=False
        for j in range(len(my_list)-1-i):
            if my_list[j]>my_list[j+1]:
                my_list[j],my_list[j+1]=my_list[j+1],my_list[j]
                swapped=True
        if not swapped:
            break
                
    return my_list
                
                
                
bubble_sort(my_list)
# Out:
# [1, 5, 9, 17, 21, 34, 47, 356]

# %% [markdown]
# # Linear Search

# %% [markdown]
# Time complexity-O(n)

# %%
my_list=[34,21,5,1,356,17,9,47,55566]

# %%
def linear_search(my_list,element):
    for index,item in enumerate(my_list):
        if item==element:
            return f'{element} is found at index {index}'
    return f' {element} is not found in list'

# %%
linear_search(my_list,8)
# Out:
# ' 8 is not found'

# %% [markdown]
# # Binary Search

# %% [markdown]
# time complexity:- O(logn)

# %%
def binary_search(my_list,element):
    my_list=sorted(my_list)
    left_index=0
    right_index=len(my_list)-1
    
    while left_index<=right_index:
        mid_index=(left_index+right_index)//2
        if element==my_list[mid_index]:
            return f'{element} is found at {mid_index}'
        else:
            if element>my_list[mid_index]:
                left_index=mid_index+1
            else:
                right_index=mid_index-1
    return f'{element} is not found'

# %%
binary_search(my_list,55566)
# Out:
# '55566 is found at 8'

# %%
my_list=[34,21,5,1,356,17,9,47,55566]

# %%
def binary_search_recursive(my_list,element,left_index,right_index):
    my_list=sorted(my_list)
    if right_index<left_index:
        return -1
    mid_index=(left_index+right_index)//2
    #mid_number=my_list[mid_index]
    if element==my_list[mid_index]:
            return f'{element} is found at {mid_index}'
    else:
        if element>my_list[mid_index]:
            left_index=mid_index+1
        else:
            right_index=mid_index-1
    return binary_search_recursive(my_list,element,left_index,right_index)

# %%
binary_search_recursive(my_list,55566,0,len(my_list)-1)
# Out:
# '55566 is found at 8'

# %% [markdown]
# # Merge Sort

# %%
def merge_sort(list1):
    if len(list1)>1:
        mid=len(list1)//2
        left_part=list1[:mid]
        right_part=list1[mid:]
        merge_sort(left_part)
        merge_sort(right_part)
        j=0
        i=0
        k=0
        while i<len(left_part) and j<len(right_part):
            if left_part[i]>right_part[j]:
                list1[k]=left_part[i]
                i+=1
                k+=1
            else:
                list1[k]=right_part[j]
                
                j+=1
                k+=1
        while i<len(left_part):
            
            list1[k]=left_part[i]
            i+=1
            k+=1
        while j<len(right_part):
            
            list1[k]=right_part[j]
            j+=1
            k+=1
            
            

m=int(input('How many numbers do you want in list'))
list1=[int(input()) for _ in range(m)]
merge_sort(list1)
print(f' the sorted list is {list1}')
# Out:
# How many numbers do you want in list5
# 23
# 2
# 56
# 7
# 21
#  the sorted list is [56, 23, 21, 7, 2]

# %% [markdown]
# # Selection Sort

# %% [markdown]
# Time complexity=O(n2)

# %%
my_list=[2,7,9,1,32,4,78,45,51]

# %%
def find_min(arr):
    min=1000000000
    for i in range(len(arr)):
        if arr[i]<min:
            min=arr[i]
    return min

my_list=[32,4,78,45,51,23,12,3]
find_min(my_list)
# Out:
# 3

# %%
def selection_sort(arr):
    size=len(arr)
    for i in range(size-1):
        min_index=i
        for j in range(min_index,size):
            if arr[j]<arr[min_index]:
                min_index=j
        if i!= min_index:
            arr[i],arr[min_index]=arr[min_index],arr[i]

# %%
selection_sort(my_list)
print(my_list)
# Out:
# [3, 4, 12, 23, 32, 45, 51, 78]

# %%
def selection_sort(my_list):
    for i in range(len(my_list)):
        min_value=min(my_list[i:])
        min_index=my_list.index(min_value,i)
        my_list[i],my_list[min_index]=my_list[min_index],my_list[i]
    return my_list

# %%
selection_sort(my_list)
# Out:
# [3, 4, 12, 23, 32, 45, 51, 78]
